# %% [markdown]
# # Advisor: Decision Theory Demo
#
# > RezpharmaCDSS | Kernel: `rezpharma_kernel`

# %%
import sys; sys.path.insert(0, '../src')from advisor.utility import ExpectedUtilityCalculatorfrom advisor.knapsack import AlertBudgetSelectorfrom advisor.cusum import CUSUMMonitorprint('Advisor loaded')

# %%
calc = ExpectedUtilityCalculator()calc.add_action('hold_drug', u_harm=-5, u_noharm=-2)calc.add_action('continue', u_harm=-30, u_noharm=0)result = calc.select_best_action(p_harm=0.65)print(f'Best action: {result["selected"]}, EU: {result["expected_utility"]:.2f}')
