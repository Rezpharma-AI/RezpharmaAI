# %% [markdown]
# # M3: Kinetic GFR Estimation
#
# > RezpharmaCDSS | Kernel: `rezpharma_kernel`

# %%
import sys; sys.path.insert(0, '../src')from m3_analysis_lab.kinetic_gfr import KineticGFRfrom m3_analysis_lab.rcv_gating import RCVGateprint('M3 loaded')

# %%
kgfr = KineticGFR(n_particles=1000)creat = [(0, 1.0), (6, 1.2), (12, 1.5), (18, 2.0), (24, 2.8)]post = kgfr.estimate(creat, muscle_mass=1.2)print(f'Kinetic GFR: {post.mean():.1f} mL/min, CI: {post.credible_interval()}')
