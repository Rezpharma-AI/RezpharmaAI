# %% [markdown]
# # M1: DDI Signal Mining
#
# > RezpharmaCDSS | Kernel: `rezpharma_kernel`

# %%
import sys; sys.path.insert(0, '../src')from m1_ddi_adr.signal_mining import EBGMSignalMinerfrom m1_ddi_adr.qt_calculator import QTcRiskCalculatorprint('M1 modules loaded')

# %%
miner = EBGMSignalMiner(alpha=0.2, beta=0.1)result = miner.detect_signal('drug_x', 'rhabdomyolysis', n_observed=5, e_expected=1.2)print(f'EBGM: {result.ebgm:.3f}, Signal: {result.is_signal}')
